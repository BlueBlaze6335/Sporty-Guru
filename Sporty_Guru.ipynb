# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0


test_labels = test_labels.reshape(-1,)
train_labels = train_labels.reshape(-1,)

# %%
class NetA:
  def net(self,X,Y,tX,tY):
    perc=models.Sequential([
                            layers.Flatten(input_shape=(32,32,3)),
                            layers.Dense(10)
    ])
    perc.compile(optimizer='SGD',
              loss='mean_squared_error',
              metrics=['accuracy'])
    perc.summary()
    #ann.fit(X,Y, epochs=10)  
    history = perc.fit(X, Y, epochs=50, 
                    validation_data=(tX, tY))  
    
    y_pred=perc.predict(tX)
    return y_pred,history

# %%
class NetB:

  def net(self,X,Y,tX,tY):
    ann = models.Sequential([
        layers.Flatten(input_shape=(32,32,3)),
        layers.Dense(300, activation='relu'),
        layers.Dense(10, activation='softmax')    
    ])

    ann.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
    ann.summary()
    #ann.fit(X,Y, epochs=10)  
    history = ann.fit(X, Y, epochs=50, 
                    validation_data=(tX, tY))  
    y_pred= ann.predict(tX)
    return y_pred,history

# %%
class NetC:

    def net(self,x,y,tx,ty):
      model = models.Sequential()
      model.add(layers.Conv2D(25 , (5,5), activation='relu', input_shape=(32,32,3),padding="same"))
      model.add(layers.MaxPooling2D((2,2),strides=2))
      model.add(layers.Flatten())
      model.add(layers.Dense(25))
      model.add(layers.Dense(10,activation="softmax"))
      model.summary()

      model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

      history = model.fit(x, y, epochs=50, 
                    validation_data=(tx, ty))  
      y_pred= model.predict(tx)
      return y_pred,history

# %%
predA,hisA =NetA().net(train_images,train_labels,test_images,test_labels)   


predB,hisB=NetB().net(train_images,train_labels,test_images,test_labels)

     
predC,hisC=NetC().net(train_images,train_labels,test_images,test_labels)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_8 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                30730
# =================================================================
# Total params: 30,730
# Trainable params: 30,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 9.4892 - accuracy: 0.0998 - val_loss: 8.4410 - val_accuracy: 0.1089
# Epoch 2/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 9.0911 - accuracy: 0.1014 - val_loss: 10.2024 - val_accuracy: 0.1026
# Epoch 3/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.9498 - accuracy: 0.1012 - val_loss: 9.1993 - val_accuracy: 0.1008
# Epoch 4/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.6640 - accuracy: 0.0994 - val_loss: 8.1258 - val_accuracy: 0.1081
# Epoch 5/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.5952 - accuracy: 0.1001 - val_loss: 7.9446 - val_accuracy: 0.1030
# Epoch 6/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.5472 - accuracy: 0.1018 - val_loss: 8.3844 - val_accuracy: 0.1010
# Epoch 7/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 8.4425 - accuracy: 0.1007 - val_loss: 8.4238 - val_accuracy: 0.1085
# Epoch 8/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.3828 - accuracy: 0.1021 - val_loss: 9.9708 - val_accuracy: 0.0983
# Epoch 9/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.3609 - accuracy: 0.1012 - val_loss: 7.7099 - val_accuracy: 0.0966
# Epoch 10/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.3488 - accuracy: 0.0990 - val_loss: 10.0045 - val_accuracy: 0.1007
# Epoch 11/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.3859 - accuracy: 0.1001 - val_loss: 18.1026 - val_accuracy: 0.1053
# Epoch 12/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.2481 - accuracy: 0.1016 - val_loss: 8.1329 - val_accuracy: 0.1046
# Epoch 13/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.3011 - accuracy: 0.1015 - val_loss: 7.7103 - val_accuracy: 0.1026
# Epoch 14/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 8.2656 - accuracy: 0.1009 - val_loss: 7.8158 - val_accuracy: 0.1111
# Epoch 15/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 8.2848 - accuracy: 0.1014 - val_loss: 7.6411 - val_accuracy: 0.1048
# Epoch 16/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.2162 - accuracy: 0.0999 - val_loss: 7.6659 - val_accuracy: 0.1035
# Epoch 17/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.2407 - accuracy: 0.0986 - val_loss: 10.0771 - val_accuracy: 0.1049
# Epoch 18/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 8.2792 - accuracy: 0.0997 - val_loss: 10.3509 - val_accuracy: 0.1076
# Epoch 19/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.3445 - accuracy: 0.0990 - val_loss: 9.1663 - val_accuracy: 0.0973
# Epoch 20/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.2384 - accuracy: 0.0995 - val_loss: 7.8406 - val_accuracy: 0.1048
# Epoch 21/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1447 - accuracy: 0.1007 - val_loss: 8.0400 - val_accuracy: 0.1034
# Epoch 22/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1915 - accuracy: 0.0985 - val_loss: 13.5628 - val_accuracy: 0.0993
# Epoch 23/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1729 - accuracy: 0.0989 - val_loss: 7.5963 - val_accuracy: 0.1010
# Epoch 24/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1728 - accuracy: 0.0992 - val_loss: 7.8191 - val_accuracy: 0.0968
# Epoch 25/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1757 - accuracy: 0.0989 - val_loss: 7.6577 - val_accuracy: 0.1045
# Epoch 26/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1445 - accuracy: 0.0997 - val_loss: 8.0142 - val_accuracy: 0.1119
# Epoch 27/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1753 - accuracy: 0.0995 - val_loss: 11.0589 - val_accuracy: 0.1017
# Epoch 28/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1714 - accuracy: 0.0986 - val_loss: 8.1850 - val_accuracy: 0.1047
# Epoch 29/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1690 - accuracy: 0.0980 - val_loss: 9.6483 - val_accuracy: 0.0970
# Epoch 30/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1853 - accuracy: 0.0993 - val_loss: 8.0878 - val_accuracy: 0.1021
# Epoch 31/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 8.1219 - accuracy: 0.0996 - val_loss: 7.6203 - val_accuracy: 0.1003
# Epoch 32/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 8.1908 - accuracy: 0.0988 - val_loss: 8.3856 - val_accuracy: 0.0991
# Epoch 33/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.2185 - accuracy: 0.0999 - val_loss: 9.1702 - val_accuracy: 0.0997
# Epoch 34/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.0896 - accuracy: 0.0991 - val_loss: 7.9225 - val_accuracy: 0.1021
# Epoch 35/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.2198 - accuracy: 0.0997 - val_loss: 9.8748 - val_accuracy: 0.0995
# Epoch 36/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1673 - accuracy: 0.0999 - val_loss: 8.1448 - val_accuracy: 0.1023
# Epoch 37/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 8.1951 - accuracy: 0.0993 - val_loss: 7.6247 - val_accuracy: 0.0999
# Epoch 38/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1733 - accuracy: 0.0983 - val_loss: 19.4396 - val_accuracy: 0.1007
# Epoch 39/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 8.1970 - accuracy: 0.0995 - val_loss: 11.5917 - val_accuracy: 0.1093
# Epoch 40/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 8.1201 - accuracy: 0.0989 - val_loss: 10.9242 - val_accuracy: 0.1040
# Epoch 41/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1443 - accuracy: 0.0991 - val_loss: 11.6260 - val_accuracy: 0.1055
# Epoch 42/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1748 - accuracy: 0.0969 - val_loss: 7.7249 - val_accuracy: 0.1059
# Epoch 43/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1459 - accuracy: 0.0984 - val_loss: 8.9563 - val_accuracy: 0.1063
# Epoch 44/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1450 - accuracy: 0.0973 - val_loss: 7.7275 - val_accuracy: 0.1025
# Epoch 45/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.2188 - accuracy: 0.0983 - val_loss: 10.9069 - val_accuracy: 0.1013
# Epoch 46/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1126 - accuracy: 0.0994 - val_loss: 10.1618 - val_accuracy: 0.0966
# Epoch 47/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.1292 - accuracy: 0.0979 - val_loss: 7.6237 - val_accuracy: 0.0923
# Epoch 48/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 8.0264 - accuracy: 0.0992 - val_loss: 9.8961 - val_accuracy: 0.1036
# Epoch 49/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 8.2141 - accuracy: 0.0985 - val_loss: 7.6638 - val_accuracy: 0.1014
# Epoch 50/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 8.2094 - accuracy: 0.0990 - val_loss: 8.1685 - val_accuracy: 0.0969
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_9 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 300)               921900
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                3010
# =================================================================
# Total params: 924,910
# Trainable params: 924,910
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.8894 - accuracy: 0.3267 - val_loss: 1.7523 - val_accuracy: 0.3741
# Epoch 2/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.7150 - accuracy: 0.3859 - val_loss: 1.6574 - val_accuracy: 0.4124
# Epoch 3/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.6490 - accuracy: 0.4157 - val_loss: 1.6558 - val_accuracy: 0.4125
# Epoch 4/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.6159 - accuracy: 0.4266 - val_loss: 1.6006 - val_accuracy: 0.4336
# Epoch 5/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.5878 - accuracy: 0.4365 - val_loss: 1.5974 - val_accuracy: 0.4333
# Epoch 6/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.5626 - accuracy: 0.4458 - val_loss: 1.5678 - val_accuracy: 0.4347
# Epoch 7/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.5448 - accuracy: 0.4509 - val_loss: 1.5740 - val_accuracy: 0.4502
# Epoch 8/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.5330 - accuracy: 0.4537 - val_loss: 1.5875 - val_accuracy: 0.4456
# Epoch 9/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.5169 - accuracy: 0.4638 - val_loss: 1.5379 - val_accuracy: 0.4548
# Epoch 10/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.5092 - accuracy: 0.4639 - val_loss: 1.5440 - val_accuracy: 0.4548
# Epoch 11/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.5013 - accuracy: 0.4684 - val_loss: 1.5318 - val_accuracy: 0.4557
# Epoch 12/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4875 - accuracy: 0.4698 - val_loss: 1.5664 - val_accuracy: 0.4427
# Epoch 13/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4804 - accuracy: 0.4722 - val_loss: 1.5347 - val_accuracy: 0.4571
# Epoch 14/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4747 - accuracy: 0.4752 - val_loss: 1.5267 - val_accuracy: 0.4565
# Epoch 15/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4615 - accuracy: 0.4807 - val_loss: 1.5467 - val_accuracy: 0.4541
# Epoch 16/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4587 - accuracy: 0.4797 - val_loss: 1.5354 - val_accuracy: 0.4523
# Epoch 17/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4525 - accuracy: 0.4840 - val_loss: 1.5229 - val_accuracy: 0.4630
# Epoch 18/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4486 - accuracy: 0.4840 - val_loss: 1.5275 - val_accuracy: 0.4609
# Epoch 19/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4426 - accuracy: 0.4854 - val_loss: 1.5377 - val_accuracy: 0.4557
# Epoch 20/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4357 - accuracy: 0.4905 - val_loss: 1.5490 - val_accuracy: 0.4579
# Epoch 21/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4313 - accuracy: 0.4923 - val_loss: 1.5143 - val_accuracy: 0.4647
# Epoch 22/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4266 - accuracy: 0.4922 - val_loss: 1.5185 - val_accuracy: 0.4627
# Epoch 23/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4241 - accuracy: 0.4942 - val_loss: 1.5267 - val_accuracy: 0.4550
# Epoch 24/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4178 - accuracy: 0.4954 - val_loss: 1.5405 - val_accuracy: 0.4583
# Epoch 25/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4154 - accuracy: 0.4957 - val_loss: 1.5253 - val_accuracy: 0.4604
# Epoch 26/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4153 - accuracy: 0.4961 - val_loss: 1.4985 - val_accuracy: 0.4662
# Epoch 27/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4115 - accuracy: 0.4990 - val_loss: 1.5544 - val_accuracy: 0.4548
# Epoch 28/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4008 - accuracy: 0.5047 - val_loss: 1.5655 - val_accuracy: 0.4548
# Epoch 29/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3984 - accuracy: 0.4993 - val_loss: 1.5329 - val_accuracy: 0.4656
# Epoch 30/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3984 - accuracy: 0.5019 - val_loss: 1.5304 - val_accuracy: 0.4606
# Epoch 31/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3954 - accuracy: 0.5020 - val_loss: 1.5623 - val_accuracy: 0.4484
# Epoch 32/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3914 - accuracy: 0.5051 - val_loss: 1.5280 - val_accuracy: 0.4508
# Epoch 33/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3848 - accuracy: 0.5078 - val_loss: 1.5093 - val_accuracy: 0.4692
# Epoch 34/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3817 - accuracy: 0.5074 - val_loss: 1.5266 - val_accuracy: 0.4645
# Epoch 35/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3837 - accuracy: 0.5064 - val_loss: 1.5365 - val_accuracy: 0.4661
# Epoch 36/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3802 - accuracy: 0.5076 - val_loss: 1.5486 - val_accuracy: 0.4584
# Epoch 37/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3729 - accuracy: 0.5131 - val_loss: 1.5324 - val_accuracy: 0.4630
# Epoch 38/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3731 - accuracy: 0.5096 - val_loss: 1.5560 - val_accuracy: 0.4618
# Epoch 39/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3715 - accuracy: 0.5107 - val_loss: 1.5410 - val_accuracy: 0.4602
# Epoch 40/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3715 - accuracy: 0.5104 - val_loss: 1.4996 - val_accuracy: 0.4751
# Epoch 41/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3666 - accuracy: 0.5124 - val_loss: 1.5211 - val_accuracy: 0.4672
# Epoch 42/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3667 - accuracy: 0.5100 - val_loss: 1.5358 - val_accuracy: 0.4598
# Epoch 43/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3574 - accuracy: 0.5164 - val_loss: 1.5233 - val_accuracy: 0.4644
# Epoch 44/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3623 - accuracy: 0.5139 - val_loss: 1.5147 - val_accuracy: 0.4682
# Epoch 45/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3557 - accuracy: 0.5165 - val_loss: 1.5359 - val_accuracy: 0.4605
# Epoch 46/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3565 - accuracy: 0.5150 - val_loss: 1.5565 - val_accuracy: 0.4572
# Epoch 47/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3534 - accuracy: 0.5139 - val_loss: 1.5669 - val_accuracy: 0.4515
# Epoch 48/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3515 - accuracy: 0.5176 - val_loss: 1.5257 - val_accuracy: 0.4665
# Epoch 49/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3459 - accuracy: 0.5211 - val_loss: 1.5180 - val_accuracy: 0.4621
# Epoch 50/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3422 - accuracy: 0.5207 - val_loss: 1.5381 - val_accuracy: 0.4655
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 25)        1900
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 25)        0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 25)                160025
# _________________________________________________________________
# dense_18 (Dense)             (None, 10)                260
# =================================================================
# Total params: 162,185
# Trainable params: 162,185
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:4930: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 1563/1563 [==============================] - 6s 3ms/step - loss: 1.4464 - accuracy: 0.4877 - val_loss: 1.3142 - val_accuracy: 0.5326
# Epoch 2/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1630 - accuracy: 0.5959 - val_loss: 1.1588 - val_accuracy: 0.5959
# Epoch 3/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0527 - accuracy: 0.6356 - val_loss: 1.1008 - val_accuracy: 0.6154
# Epoch 4/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9875 - accuracy: 0.6599 - val_loss: 1.1034 - val_accuracy: 0.6216
# Epoch 5/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9376 - accuracy: 0.6772 - val_loss: 1.0898 - val_accuracy: 0.6276
# Epoch 6/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9003 - accuracy: 0.6865 - val_loss: 1.1424 - val_accuracy: 0.6129
# Epoch 7/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8664 - accuracy: 0.7022 - val_loss: 1.1805 - val_accuracy: 0.5992
# Epoch 8/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8342 - accuracy: 0.7115 - val_loss: 1.1501 - val_accuracy: 0.6154
# Epoch 9/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8095 - accuracy: 0.7194 - val_loss: 1.1210 - val_accuracy: 0.6381
# Epoch 10/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7880 - accuracy: 0.7260 - val_loss: 1.1464 - val_accuracy: 0.6243
# Epoch 11/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7696 - accuracy: 0.7338 - val_loss: 1.1834 - val_accuracy: 0.6260
# Epoch 12/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7492 - accuracy: 0.7415 - val_loss: 1.1524 - val_accuracy: 0.6299
# Epoch 13/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7277 - accuracy: 0.7473 - val_loss: 1.1829 - val_accuracy: 0.6303
# Epoch 14/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7138 - accuracy: 0.7508 - val_loss: 1.2294 - val_accuracy: 0.6238
# Epoch 15/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6995 - accuracy: 0.7566 - val_loss: 1.2689 - val_accuracy: 0.6161
# Epoch 16/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6829 - accuracy: 0.7607 - val_loss: 1.2509 - val_accuracy: 0.6169
# Epoch 17/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6630 - accuracy: 0.7680 - val_loss: 1.2508 - val_accuracy: 0.6314
# Epoch 18/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6550 - accuracy: 0.7712 - val_loss: 1.2926 - val_accuracy: 0.6132
# Epoch 19/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6396 - accuracy: 0.7749 - val_loss: 1.2812 - val_accuracy: 0.6187
# Epoch 20/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6282 - accuracy: 0.7794 - val_loss: 1.2974 - val_accuracy: 0.6241
# Epoch 21/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6156 - accuracy: 0.7853 - val_loss: 1.3467 - val_accuracy: 0.6134
# Epoch 22/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6063 - accuracy: 0.7858 - val_loss: 1.3430 - val_accuracy: 0.6187
# Epoch 23/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5946 - accuracy: 0.7916 - val_loss: 1.4152 - val_accuracy: 0.6096
# Epoch 24/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5854 - accuracy: 0.7939 - val_loss: 1.4013 - val_accuracy: 0.6110
# Epoch 25/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5760 - accuracy: 0.7948 - val_loss: 1.4301 - val_accuracy: 0.6137
# Epoch 26/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5625 - accuracy: 0.8001 - val_loss: 1.4308 - val_accuracy: 0.6137
# Epoch 27/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5561 - accuracy: 0.8050 - val_loss: 1.5252 - val_accuracy: 0.6026
# Epoch 28/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5499 - accuracy: 0.8069 - val_loss: 1.4856 - val_accuracy: 0.6075
# Epoch 29/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5386 - accuracy: 0.8091 - val_loss: 1.5370 - val_accuracy: 0.6023
# Epoch 30/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5309 - accuracy: 0.8123 - val_loss: 1.5732 - val_accuracy: 0.5897
# Epoch 31/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5266 - accuracy: 0.8142 - val_loss: 1.5713 - val_accuracy: 0.5934
# Epoch 32/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5216 - accuracy: 0.8137 - val_loss: 1.5871 - val_accuracy: 0.5972
# Epoch 33/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5121 - accuracy: 0.8169 - val_loss: 1.6029 - val_accuracy: 0.6022
# Epoch 34/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5032 - accuracy: 0.8187 - val_loss: 1.6905 - val_accuracy: 0.5951
# Epoch 35/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4970 - accuracy: 0.8244 - val_loss: 1.6600 - val_accuracy: 0.5954
# Epoch 36/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4902 - accuracy: 0.8251 - val_loss: 1.6729 - val_accuracy: 0.5994
# Epoch 37/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4845 - accuracy: 0.8275 - val_loss: 1.6981 - val_accuracy: 0.5984
# Epoch 38/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4793 - accuracy: 0.8281 - val_loss: 1.6993 - val_accuracy: 0.6056
# Epoch 39/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4705 - accuracy: 0.8319 - val_loss: 1.7268 - val_accuracy: 0.5969
# Epoch 40/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4668 - accuracy: 0.8345 - val_loss: 1.7366 - val_accuracy: 0.6051
# Epoch 41/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4613 - accuracy: 0.8361 - val_loss: 1.8175 - val_accuracy: 0.5939
# Epoch 42/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4561 - accuracy: 0.8386 - val_loss: 1.8500 - val_accuracy: 0.5874
# Epoch 43/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4530 - accuracy: 0.8372 - val_loss: 1.8465 - val_accuracy: 0.5955
# Epoch 44/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4462 - accuracy: 0.8396 - val_loss: 1.8309 - val_accuracy: 0.5931
# Epoch 45/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4356 - accuracy: 0.8450 - val_loss: 1.9164 - val_accuracy: 0.5856
# Epoch 46/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4326 - accuracy: 0.8457 - val_loss: 1.8893 - val_accuracy: 0.5997
# Epoch 47/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4319 - accuracy: 0.8434 - val_loss: 1.8857 - val_accuracy: 0.5968
# Epoch 48/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4248 - accuracy: 0.8499 - val_loss: 1.9176 - val_accuracy: 0.5913
# Epoch 49/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4231 - accuracy: 0.8498 - val_loss: 1.9213 - val_accuracy: 0.5923
# Epoch 50/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4114 - accuracy: 0.8541 - val_loss: 2.0596 - val_accuracy: 0.5800

# %%
y_A = [np.argmax(element) for element in predA]
y_B= [np.argmax(element) for element in predB]
y_C=[np.argmax(element) for element in predC]

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %% [markdown]
# ## Plots for NetA :
# title - truth
# label - prediction

# %%
plt.figure(figsize=(12,12))
plt.title("Plot for NetA")
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i])
    plt.title(classes[test_labels[i]])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(classes[y_A[i]])
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## Plots for NetB :
# title - truth
# label - prediction

# %%
plt.figure(figsize=(12,12))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i])
    plt.title(classes[test_labels[i]])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(classes[y_B[i]])
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## Plots for NetC :
# title - truth
# label - prediction

# %%
plt.figure(figsize=(12,12))
plt.title("Plot for NetA")
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i])
    plt.title(classes[test_labels[i]])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(classes[y_C[i]])
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %%
maxA=sorted(hisA.history['accuracy'],reverse=True)
acrA=str(maxA[0]*100)
maxB=sorted(hisB.history['accuracy'],reverse=True)
acrB=str(maxB[0]*100)
maxC=sorted(hisC.history['accuracy'],reverse=True)
acrC=str(maxC[0]*100)
maxAV=sorted(hisA.history['val_accuracy'],reverse=True)
acrAV=str(maxAV[0]*100)
maxBV=sorted(hisB.history['val_accuracy'],reverse=True)
acrBV=str(maxBV[0]*100)
maxCV=sorted(hisC.history['val_accuracy'],reverse=True)
acrCV=str(maxCV[0]*100)

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
fig, axs = plt.subplots(3, 1,figsize=(15,15))
axs[0].set_title("Accuracy of NetA")
axs[0].plot(hisA.history['accuracy'], label='NetA accuracy',color='orange')
axs[0].plot(hisA.history['val_accuracy'], label = 'NetA val_accuracy',color='blue')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Accuracy')
axs[0].legend(loc='lower right')
axs[0].text(0.1,0.9,'Max train accuracy - '+acrA+' %', verticalalignment='center', transform=axs[0].transAxes)
axs[0].text(0.1,0.8,'Max val accuracy - '+acrAV+' %', verticalalignment='center', transform=axs[0].transAxes)
axs[1].set_title("Accuracy of NetB")
axs[1].plot(hisB.history['accuracy'], label='NetB accuracy',color='red')
axs[1].plot(hisB.history['val_accuracy'], label = 'NetB val_accuracy',color='black')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')
axs[1].legend(loc='lower right')
axs[1].text(0.1,0.9,'Max train accuracy - '+acrB+' %', verticalalignment='center', transform=axs[1].transAxes)
axs[1].text(0.1,0.8,'Max val accuracy - '+acrBV+' %', verticalalignment='center', transform=axs[1].transAxes)
axs[2].set_title("Accuracy of NetC")
axs[2].plot(hisC.history['accuracy'], label='NetC accuracy',color='purple')
axs[2].plot(hisC.history['val_accuracy'], label = 'NetC val_accuracy',color='cyan')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Accuracy')
axs[2].legend(loc='lower right')
axs[2].text(0.1,0.9,'Max train accuracy - '+acrC+' %', verticalalignment='center', transform=axs[2].transAxes)
axs[2].text(0.1,0.8,'Max val accuracy - '+acrCV+' %', verticalalignment='center', transform=axs[2].transAxes)
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)   
plt.show()
